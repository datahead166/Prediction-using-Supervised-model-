# %% [markdown]
# PREDICTION USING SUPERVISED MODEL.
#
#
# Simple Linear Regression Task.

# %%
# Importing all libraries required in this notebook
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Reading data from remote link
url = "http://bit.ly/w-data"
s_data = pd.read_csv(url)
print("Data imported successfully")

s_data.head(10)
# Out:
# Data imported successfully
#    Hours  Scores
# 0    2.5      21
# 1    5.1      47
# 2    3.2      27
# 3    8.5      75
# 4    3.5      30
# 5    1.5      20
# 6    9.2      88
# 7    5.5      60
# 8    8.3      81
# 9    2.7      25
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['Hours'].plot(kind='hist', bins=20, title='Hours')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['Scores'].plot(kind='hist', bins=20, title='Scores')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_2.plot(kind='scatter', x='Hours', y='Scores', s=32, alpha=.8)
# ...

# %% [markdown]
# Let's plot our data points on 2-D graph to eyeball our dataset and see if we can manually find any relationship between the data. We can create the plot with the following script:

# %%
# Plotting the distribution of scores
s_data.plot(x='Hours', y='Scores', style='o')
plt.title('Hours vs Score')
plt.xlabel('Hours Studied')
plt.ylabel('Score')
plt.show()

# %% [markdown]
#  The chart indicates that students who spend more time studying tend to achieve higher scores. There's a noticeable upward trend showing that as study hours go up, so do the scores. This pattern points to a positive correlation: more studying is associated with better performance.

# %% [markdown]
# **`Preparing the data`**
#
#
# The next step is to divide the data into "attributes" (inputs) and "labels" (outputs).

# %%
X = s_data.iloc[:, :-1].values
y = s_data.iloc[:, 1].values

# %% [markdown]
# Now that we have our attributes and labels, the next step is to split this data into training and test sets. We'll do this by using Scikit-Learn's built-in train_test_split() method:

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y,
                            test_size=0.2, random_state=0)

# %% [markdown]
# # Training the Algorithm

# %% [markdown]
# We have split our data into training and testing sets, and now is finally the time to train our algorithm.

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train, y_train)

print("Training complete.")
# Out:
# Training complete.

# %%
# Plotting the regression line
line = regressor.coef_*X+regressor.intercept_

# Plotting for the test data
plt.scatter(X, y)
plt.plot(X, line);
plt.show()

# %% [markdown]
# ### **Making Predictions**
# Now that we have trained our algorithm, it's time to make some predictions.
# Making Predictions
# Now that we have trained our algorithm, it's time to make some predictions.

# %%
print(X_test) # Testing data - In Hours
y_pred = regressor.predict(X_test) # Predicting the scores
# Out:
# [[1.5]
#  [3.2]
#  [7.4]
#  [2.5]
#  [5.9]]

# %%
# Comparing Actual vs Predicted
df = pd.DataFrame({'Actual': y_test, 'Predicted': y_pred})
df
# Out:
#    Actual  Predicted
# 0      20  16.884145
# 1      27  33.732261
# 2      69  75.357018
# 3      30  26.794801
# 4      62  60.491033

# %%
# Assuming 'regressor' is your trained regression model
hours = 9.25
# Reshape the input
hours_reshaped = np.array([[hours]])
# Make a prediction with the reshaped input
own_pred = regressor.predict(hours_reshaped)
print("No of Hours = {}".format(hours))
print("Predicted Score = {}".format(own_pred[0]))
# Out:
# No of Hours = 9.25
# Predicted Score = 93.69173248737539

# %%
# Assuming 'regressor' is your trained regression model
hours = 8.5
# Reshape the input
hours_reshaped = np.array([[hours]])
# Make a prediction with the reshaped input
own_pred = regressor.predict(hours_reshaped)
print("No of Hours = {}".format(hours))
print("Predicted Score = {}".format(own_pred[0]))
# Out:
# No of Hours = 8.5
# Predicted Score = 86.25874012689371

# %%
# Assuming 'regressor' is your trained regression model
hours = 6.85
# Reshape the input
hours_reshaped = np.array([[hours]])
# Make a prediction with the reshaped input
own_pred = regressor.predict(hours_reshaped)
print("No of Hours = {}".format(hours))
print("Predicted Score = {}".format(own_pred[0]))
# Out:
# No of Hours = 6.85
# Predicted Score = 69.90615693383401

# %%
# Assuming 'regressor' is your trained regression model
hours = 9.0
# Reshape the input
hours_reshaped = np.array([[hours]])
# Make a prediction with the reshaped input
own_pred = regressor.predict(hours_reshaped)
print("No of Hours = {}".format(hours))
print("Predicted Score = {}".format(own_pred[0]))
# Out:
# No of Hours = 9.0
# Predicted Score = 91.21406836721482

# %% [markdown]
# **EVALUATING THE MODEL**
#
#
# The last phase involves assessing how effectively the algorithm works. This evaluation is crucial for determining the relative performance of various algorithms on the same data set. For our purposes, we're using the mean square error as our metric of choice, although it's worth noting there are numerous other metrics that could also be used for this purpose.

# %%
from sklearn import metrics
print('Mean Absolute Error:',
      metrics.mean_absolute_error(y_test, y_pred))
# Out:
# Mean Absolute Error: 4.183859899002982
